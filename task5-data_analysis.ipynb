# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rasik\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

df = pd.read_csv('sales_data.csv')
print(df.head())
# Out:
#       Product  Sales Region
# 0      Laptop   1200  North
# 1  Smartphone    800  South
# 2      Tablet    450   East
# 3      Laptop   1400  South
# 4  Smartphone    900  North

# %%
grouped_data = df.groupby('Product')['Sales'].sum()
print(grouped_data)
# Out:
# Product
# Laptop        3900
# Smartphone    2400
# Tablet        1420
# Name: Sales, dtype: int64

# %%
import matplotlib.pyplot as plt

grouped_data.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.show()
